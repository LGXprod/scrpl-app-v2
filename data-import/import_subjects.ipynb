# %%
import os
import json
import uuid

from dotenv import dotenv_values
import weaviate
import weaviate.classes as wvc

# %%
config = dotenv_values("../.env")

# %%
# function that reads json file
def read_json(file):
    with open(file, "r") as f:
        data = json.load(f)
    return data

# %%
weaviate_api_key = config["AUTHENTICATION_APIKEY_ALLOWED_KEYS"].split(",")[0]

# %%
client = weaviate.connect_to_custom(
    http_host="localhost",
    http_port=8080,
    http_secure=False,
    grpc_host="localhost",
    grpc_port=50051,
    grpc_secure=False,
    auth_credentials=weaviate.auth.AuthApiKey(
        weaviate_api_key
    ),  # Set this environment variable
)

# %%
client.collections.delete("Subject")

# %%
subjects = client.collections.create(
    "Subject",
    vectorizer_config=wvc.config.Configure.Vectorizer.none(),
    vector_index_config=wvc.config.Configure.VectorIndex.hnsw(
        distance_metric=wvc.config.VectorDistances.COSINE  # select prefered distance metric
    ),
)

# %%
with open("subject_data/subject_code_to_name.json") as f:
    subject_code_to_name = json.load(f)

with open("subject_data/subject_to_degrees.json") as f:
    subject_to_degrees = json.load(f)

with open("subject_data/subject_to_majors.json") as f:
    subject_to_majors = json.load(f)

# %%
subject_weaviate_objects = []

for uni in os.listdir("./subject_data/embeddings"):
    if not os.path.isdir(f"./subject_data/embeddings/{uni}"):
        continue

    for subject_filename in os.listdir(f"./subject_data/embeddings/{uni}"):
        if not subject_filename.endswith(".json"):
            continue

        subject_code = subject_filename.split(".")[0]
        subject_id = str(uuid.uuid5(uuid.NAMESPACE_DNS, f"{uni}-{subject_code}"))

        subject_embedding = read_json(
            f"./subject_data/embeddings/{uni}/{subject_filename}"
        )

        subject_weaviate_objects.append(
            wvc.data.DataObject(
                uuid=subject_id,
                properties={
                    "subjectCode": subject_code,
                    "name": subject_code_to_name.get(subject_code, subject_code),
                    "university": uni.upper(),
                    "degrees": subject_to_degrees[subject_code],
                    "majors": subject_to_majors[subject_code],
                },
                vector=subject_embedding,
            )
        )

# %%
subjects.data.insert_many(subject_weaviate_objects)
# Out:
# BatchObjectReturn(all_responses=[UUID('7afdd291-1e8c-56d1-9b43-f33ccfdd7a69'), UUID('a10d0335-af61-5879-a19f-2fa2171d6599'), UUID('9f165be4-2e25-59cb-b7c6-369e226b4eed'), UUID('2abec3ee-7035-5c45-829f-47bd633089dd'), UUID('cbb83c81-72e5-54b5-8af3-28f49127d295'), UUID('4e3696e5-fdba-5a27-b329-d17a83efe503'), UUID('c4e3f7be-a41c-54e2-8769-9973b4efa962'), UUID('a3264daa-2946-5c4e-9d02-87ef8b545dea'), UUID('788e2104-3625-5155-a83f-e7ba3ea11df6'), UUID('8b36ac41-a9ef-52fa-8489-ae7e244e53e3'), UUID('5d869bb1-8fea-5575-afe8-7ae25c4ccaae'), UUID('7eeb0b29-8f5e-53b2-b2b5-10ae118a8dc4'), UUID('61b62eaa-d0b8-5b39-a230-38e46c7a0e8b'), UUID('e3d9187f-0416-5d2c-a70e-a6a59dc604b8'), UUID('ca441d4a-8513-5175-a727-97416f1bfcfd'), UUID('b296b848-e609-575a-be4b-dbe29e19ad92'), UUID('fd3f3283-ffdc-5e41-9420-f041c8957dfb'), UUID('35a61263-f8cd-5a32-ab77-8bba76be08a4'), UUID('4f378200-975a-5705-84d7-2686956883b9'), UUID('221ef27a-00f8-594e-bc84-5947a1f822d7'), UUID('9d90a970-7743-5112-a332-0c88361e1f31'), UUID('80eafc51-3d29-5723-9ca3-74fac4e7ba20'), UUID('5607749f-e423-5f02-9b2c-39be0f762988'), UUID('5705c5af-a83d-5941-8d91-270f8b0eda1c'), UUID('d37a4ced-4578-5f93-8899-a10374f1f6e4'), UUID('44a086be-3a7e-555e-bb63-f6eeb5602a29'), UUID('de6426c3-bca3-5169-9549-877455c8e02a'), UUID('7b057756-6bff-577e-8f16-de15c692aa31'), UUID('00d1cc5c-1ea0-550e-8942-bbb5d10588a3'), UUID('0a0ac200-5f2d-5da8-9ce1-6c57531847cd'), UUID('6b6acd65-3dea-5c06-a6b9-d5608ecce8d1'), UUID('ebd3a55e-4c98-5293-9a7b-bae6d003b89e'), UUID('6e23aab7-579d-5540-abfe-5fd67ec06d88'), UUID('d324fd38-992c-59ed-853f-af260a050e85'), UUID('01e08eba-860a-5b9b-8d62-5db9f26df04b'), UUID('fd8ba0fa-39ef-58a5-b096-96f4c595225a'), UUID('720b9819-b2f6-54dc-b647-d3c49af6851b'), UUID('857420e5-5cbc-5ba8-98be-df9ad255bb9e'), UUID('2b779a7a-6377-5233-8372-64240b9b06a7'), UUID('89f3e389-3049-5c59-85a3-06bdac0a01ef'), UUID('61615dde-7a39-5198-a910-b8467a1d9d20'), UUID('c55096b4-2b1e-5a1d-8b1d-8cacd824ab72'), UUID('a935b1bc-c418-5832-8712-b61a3fc8b043'), UUID('e9846d65-f1da-58ce-a284-e3f70a21ccec'), UUID('bfbc8628-a685-53ed-8098-41621b9f1f23'), UUID('94193d28-6617-515d-986b-759c5f541a58'), UUID('85faf73d-3502-57fa-bab6-e74be7a27438'), UUID('0649e890-b9f4-59d6-9213-8bfeb5ebcf1a'), UUID('90e3b6db-aa8a-5a32-a6e2-d9a7b9567971'), UUID('63045fb0-3a53-5d71-be06-cd33e8d8a8c3'), UUID('a76a2dc6-49e5-5330-82ff-271aac05049e'), UUID('58d6b2de-13ba-5aef-974d-7e7d8593ce25'), UUID('79c0e385-29d8-5ca8-a1d1-e19671e76525'), UUID('587eae16-1666-55d6-ba8e-8c110670d997'), UUID('b3582cae-0b67-5a27-ac82-6ad205c220d8'), UUID('6528d8fe-0400-5441-a4f2-30ce38e420dd'), UUID('84d60fb8-8c5e-596b-a71f-a77382d0cec8'), UUID('78994689-15f1-5eb7-a857-2b425033210e'), UUID('5ec40776-841d-5941-91d8-6716a02d8d0e'), UUID('e34e1615-3248-5145-bc29-5dca4fa421d8'), UUID('f21a407a-41b6-5ee4-a5c2-c2f8f5dcfb56'), UUID('35530920-d0ca-548b-8e7f-313ceb00cdd3'), UUID('98710888-6ca5-5d21-b005-3d7506da2441'), UUID('84af1ddb-f4c5-538b-ac70-220b05e64aa4'), UUID('e74d82f8-40ea-53fa-a263-7931fda30007'), UUID('8c21c2bb-2ea1-5496-811f-43f3dc70806c'), UUID('0d0e2e88-6d45-5de5-a6a0-136b1518415b'), UUID('26d79804-97b6-56d7-a9e3-4a2039c1ce2a'), UUID('18ea86d3-c551-55a8-a8ae-3022d03f6624'), UUID('1e0959f0-8574-559d-9bb7-7418c32d21bd'), UUID('6d0dfb00-980a-5b35-9df5-c8e64c227626'), UUID('5a4b1d6e-b07f-5b97-966a-603be32989dd'), UUID('c7962100-1ed1-557a-8aa2-025116c3d01a'), UUID('598d64bf-e824-5cfc-ba00-b26c106beb11'), UUID('523c7948-d8cd-5d61-af3e-e674d68cd550'), UUID('eb69b358-f533-547b-b588-eb2abb26aaa0'), UUID('629b5525-9e46-562d-b0fa-c9b461487ca7'), UUID('8a8fab83-9b7f-5712-9c64-f9b95258a6a4'), UUID('0c1c62c3-a857-52a6-920d-7334643e11fe'), UUID('498a7cc4-f4dd-553e-8720-a181362a3a47'), UUID('2bdadfe2-e25e-5ffd-8fe2-b9bef4583573'), UUID('c80f7939-cbf1-56b8-b8bc-3869ef7fb434'), UUID('9d7f4d31-fa04-5421-b5b7-1fb30e9de9a7'), UUID('1566089c-6c0a-5b55-abad-b831f9a71002'), UUID('f992333e-398b-540c-bfed-76c9a1b23e78'), UUID('a3dbfacb-ee25-5a8f-ba16-8985869c2a7d'), UUID('f8185 ...

# %%
print(
    subjects.query.fetch_object_by_id(
        "7afdd291-1e8c-56d1-9b43-f33ccfdd7a69", include_vector=True
    ).vector
)
# Out:
# {'default': [0.030688438564538956, -0.0013925213133916259, 0.02559700980782509, -0.017014268785715103, 0.005993809085339308, -0.0746903270483017, -0.09490004181861877, 0.021492144092917442, -0.042022913694381714, -0.01241435669362545, -0.008256797678768635, 0.06625650823116302, -0.0055818078108131886, -0.09669041633605957, -0.02875162661075592, 0.02735813334584236, 0.009058274328708649, -0.061619535088539124, -0.028259504586458206, 0.0017427615821361542, -0.01703542470932007, 0.006391908973455429, -0.05140922963619232, 0.051324158906936646, -0.06361517310142517, -0.052826885133981705, -0.011759343557059765, -0.02733600325882435, -0.02576264925301075, 0.03314208984375, 0.04999025538563728, -0.02504749968647957, 0.019766950979828835, -0.031993523240089417, 0.009822833351790905, -0.0007116939523257315, -0.008562606759369373, -0.041862450540065765, 0.023994864895939827, -0.009662508033216, 0.046809758991003036, 0.04205669090151787, 0.029405293986201286, -0.0007488352130167186, 0.02568567544221878, 0.006915752310305834, 0.031304772943258286, -0.008131597191095352, 0.046574514359235764, -0.03479161113500595, -0.0080683259293437, -0.02025957964360714, 0.014399424195289612, -0.042540695518255234, -0.0011999799171462655, -0.039931412786245346, -0.02324160374701023, -0.002127085579559207, -0.0324869230389595, 0.02692175842821598, 0.025363733991980553, 0.014988581649959087, 0.001438097795471549, 0.011494364589452744, 0.029818473383784294, 0.058242056518793106, 0.031960804015398026, 0.0004024198278784752, -0.0016171014867722988, 0.008827729150652885, -0.0015946723287925124, 0.05026323348283768, -0.011213021352887154, 0.024711156263947487, -0.07220132648944855, 0.05526546388864517, 0.006350913550704718, 0.026599889621138573, 0.011481650173664093, -0.028694259002804756, -0.05983410403132439, 0.051686741411685944, -0.057492613792419434, 0.027344904839992523, -0.028191404417157173, 0.053625669330358505, 0.0073959496803581715, 0.058609604835510254, 0.08772730827331543, 0.04291205853223801, -0.01286687795072794, -0.03137669712305069, 0.001995543483644724, 0.010434683412313461, -0.019921695813536644, 0.01933835633099079, 0.06912028044462204, -0.012352440506219864, -0.0052091688849031925, -0.030767245218157768, -0.008134251460433006, 0.046076450496912, -0.04025799781084061, -0.0462191142141819, 0.045012615621089935, -0.02221742831170559, 0.003043987788259983, 0.04749585688114166, 0.0268805380910635, 0.02511504851281643, 0.05442146956920624, 0.06679898500442505, 0.025560129433870316, -0.02208070643246174, 0.07343533635139465, -0.031038697808980942, 0.06790328025817871, 0.0064896163530647755, -0.001873286790214479, 0.03930417448282242, 0.020610053092241287, -0.002685215789824724, 0.031175093725323677, 0.058406658470630646, 0.03893251344561577, 0.011925187893211842, 0.037126000970602036, -0.02742907591164112, 0.030867505818605423, -0.03259991854429245, 0.01270707044750452, -0.0010247105965390801, 0.013870296999812126, -0.020004449412226677, 0.056978728622198105, -0.0949363261461258, 0.018099648877978325, -0.0013110446743667126, -0.03055398538708687, -0.047936953604221344, 0.012097888626158237, -0.003284393809735775, 0.03594746068120003, -0.048267412930727005, -0.03782155364751816, -0.0230239387601614, 5.9069821872981265e-05, -0.02080596797168255, 0.01356368139386177, 0.05643053725361824, -0.06228883937001228, 0.00466384319588542, 0.03400987386703491, -0.009555000811815262, 0.014963681809604168, 0.0014942326815798879, -0.022880157455801964, -0.004759159870445728, -0.02923797257244587, -0.016417134553194046, 0.027155524119734764, -0.05618322268128395, -0.03964350372552872, 0.039597634226083755, -0.002633066847920418, 0.021529853343963623, 0.006260031834244728, 0.009464038535952568, -0.0044424040243029594, 0.0056401267647743225, 0.030925972387194633, -0.046982843428850174, -0.031466320157051086, -0.012763869017362595, 0.05173084884881973, -0.013902920298278332, -0.028913116082549095, 0.021197665482759476, 0.061713796108961105, 0.021898604929447174, -0. ...

# %%
client.close()
